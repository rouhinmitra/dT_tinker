# %%
import ee
import pandas as pd 
import numpy as np
import folium
from folium import plugins

# %% [markdown]
# ### Calculating Evapotranspiration using Landsat
# 1. We will calculate ET using the residual energy balance method
# - Net radiation (Rn)
# - Soil Heat flux (G)
# - Sensible Heat flux (H)
#
# Then calculate $ LE=R_{n} - H - G $

# %% [markdown]
# ### 1. Process Landsat
# - Select a Landsat Image
# - Visualize
# - Get details
# - Cloud Mask

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=K8_vx2GEI1rJkBJrSc6NRcATzRTqa_Vc6OLP0Y6YcoU&tc=c9-_vDnzSX6pAVh8cd-vycC-AfHoTyi90ySxQ960-5o&cc=zzHoGFVjpgu01XImeC-6v9-PcZobef_n5qlKsyZZfQg>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=K8_vx2GEI1rJkBJrSc6NRcATzRTqa_Vc6OLP0Y6YcoU&tc=c9-_vDnzSX6pAVh8cd-vycC-AfHoTyi90ySxQ960-5o&cc=zzHoGFVjpgu01XImeC-6v9-PcZobef_n5qlKsyZZfQg</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# Get a <10% cloudy landsat image of the central valley 
# LANDSAT/LC08/C02/T1_L2/LC08_043034_20220402
geometry=ee.Geometry.Point([-121.189405,37.615426])
# Get the image collection 
ls=ee.ImageCollection("LANDSAT/LC08/C02/T1_L2").filterDate("2022-04-01","2022-09-30").filterMetadata('CLOUD_COVER', 'less_than', 5).filterBounds(geometry);
print("The image collection has", ls.size().getInfo(), "images")
## Scale the images 
## Why do we need to scale? (Refer the slides)
def applyScaleFactors(image):
        opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2);
        thermalBands = image.select('ST_B.*').multiply(0.00341802).add(149.0);
        return image.addBands(opticalBands, None, True).addBands(thermalBands, None, True)
ls=ls.map(applyScaleFactors)
#Get the first image
ls_first=ls.first()
# Out:
# The image collection has 11 images

# %% [markdown]
# #### Visualize Image

# %%
# Add custom basemaps to folium
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )}

# %%
# Define a method for displaying Earth Engine image tiles on a folium map.
def add_ee_layer(self, ee_object, vis_params, name):
    
    try:    
        # display ee.Image()
        if isinstance(ee_object, ee.image.Image):    
            map_id_dict = ee.Image(ee_object).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
            ).add_to(self)
        # display ee.ImageCollection()
        elif isinstance(ee_object, ee.imagecollection.ImageCollection):    
            ee_object_new = ee_object.mosaic()
            map_id_dict = ee.Image(ee_object_new).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
            ).add_to(self)
        # display ee.Geometry()
        elif isinstance(ee_object, ee.geometry.Geometry):    
            folium.GeoJson(
            data = ee_object.getInfo(),
            name = name,
            overlay = True,
            control = True
        ).add_to(self)
        # display ee.FeatureCollection()
        elif isinstance(ee_object, ee.featurecollection.FeatureCollection):  
            ee_object_new = ee.Image().paint(ee_object, 0, 2)
            map_id_dict = ee.Image(ee_object_new).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
        ).add_to(self)
    
    except:
        print("Could not display {}".format(name))
    
# Add EE drawing method to folium.
folium.Map.add_ee_layer = add_ee_layer

# %%
# Set visualization parameters.
# vis_params = {
#   'min': 0,
#   'max': 4000,
#   'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}
vis_params = {
  'bands': ['SR_B5', 'SR_B4', 'SR_B3'],
  'min': 0.0,
  'max': 0.3,
};
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)

# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_first, vis_params, 'False Color composite Image')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c80fc487f426220a152de09ce6170f8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c80fc487f426220a152de09ce6170f8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c80fc487f426220a152de09ce6170f8c = L.map(
#                 &quot;map_c80fc487f426220a152de09ce6170f8c&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_099d2f5a36c79894c99c1f9f237c18d1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
#
#             var tile_layer_1afb2a0387059b925c988d6c034502d9 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
#
#             var tile_layer_2806cb6f3239527b5a56eb10878f6aef = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/71577c5c0a99b7fc1fc41f15c647fd3a-a116a3e73120936806c3d65e2cc9a539/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
#
#             var layer_control_ecba0f537dce39f7f0ce72d95a2b974f = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_099d2f5a36c79894c99c1f9f237c18d1,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Google Satellite&quot; : tile_layer_1afb2a0387059b925c988d6c034502d9,
#                     &quot;False Color composite Image&quot; : tile_layer_2806cb6f3239527b5a56eb10878f6aef,
#                 },
#             };
#             L.control.layers(
#                 layer_control_ecba0f537dce39f7f0ce72d95a2b974f.base_layers,
#                 layer_control_ecba0f537dce39f7f0ce72d95a2b974f.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c80fc487f426220a152de09ce6170f8c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
### Get Image details 
landsat_version=ls_first.get('L1_LANDSAT_PRODUCT_ID').getInfo()
print(landsat_version)
sun_elevation=ls_first.get("SUN_ELEVATION")
print("Sun Elevation ", sun_elevation.getInfo())
time_start=ls_first.get('system:time_start')
date=ee.Date(time_start)
year=ee.Number(date.get('year'))
month=ee.Number(date.get('month'))
day=ee.Number(date.get('day'))
hour=ee.Number(date.get('hour'))
minuts = ee.Number(date.get('minutes'))
print("Time of Image ", day.getInfo(),"/",month.getInfo(),"/",year.getInfo(), "@" , hour.getInfo(), ":",minuts.getInfo())
# Out:
# LC08_L1TP_043034_20220504_20220511_02_T1
# Sun Elevation  62.39250282
# Time of Image  4 / 5 / 2022 @ 18 : 39

# %%
date_string=date.format('YYYY-MM-dd').getInfo()

# %%
## Change Band Names (makes it easier to read)
print("Current Band Names: ",ls_first.bandNames().getInfo())
ls_first=ls_first.select([0,1,2,3,4,5,6,8,17], ["UB","B","GR","R","NIR","SWIR_1","SWIR_2","ST_B10","pixel_qa"])
print("New Band Names: ",ls_first.bandNames().getInfo())
# Out:
# Current Band Names:  ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'SR_QA_AEROSOL', 'ST_B10', 'ST_ATRAN', 'ST_CDIST', 'ST_DRAD', 'ST_EMIS', 'ST_EMSD', 'ST_QA', 'ST_TRAD', 'ST_URAD', 'QA_PIXEL', 'QA_RADSAT']
# New Band Names:  ['UB', 'B', 'GR', 'R', 'NIR', 'SWIR_1', 'SWIR_2', 'ST_B10', 'pixel_qa']

# %% [markdown]
# #### Cloud Mask
# Our image is <10% cloudy so we don't need to mask, but in general images can get cloudy. These cloudy pixels need to be removed (or made null)
#
# To do that, we take help of the "pixel_qa" band from Landsat

# %%
# def f_cloudMaskL8_SR(image):
#     quality = image.select('pixel_qa');
#     ## Keep pixels than are clear and low confidence on clouds
#     c01 = quality.eq(21824); 
#     c02 = quality.eq(21952); 
#     c03=quality.eq(21888) 
#     c04 = quality.eq(21756);
#     mask = c01.Or(c02).Or(c03).Or(c04);
#     return image.updateMask(mask);
# ls_cloud=f_cloudMaskL8_SR(ls_first)

# %% [markdown]
# ## 1. Net Radiation
# - Albedo
# - Get ancilliary data
# - Transmissivity
# - $SW_{IN}$
# - $LW_{OUT}$
# - Cold pixel selection
# - $LW_{IN}$

# %% [markdown]
# ##### a) Albedo

# %%
def f_albedoL8(image):
    alfa = image.expression(
      '(0.130*B1) + (0.115*B2) + (0.143*B3) + (0.180*B4) + (0.281*B5) + (0.108*B6) + (0.042*B7)',{  #// (Ke, Im  et al 2016)
        'B1' : image.select(['UB']),
        'B2' : image.select(['B']),
        'B3' : image.select(['GR']),
        'B4' : image.select(['R']),
        'B5' : image.select(['NIR']),
        'B6' : image.select(['SWIR_1']),
        'B7' : image.select(['SWIR_2'])
      }).rename('ALFA');
    return image.addBands(alfa);
ls_first=f_albedoL8(ls_first)

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['ALFA'],
  'min': 0.0,
  'max': 0.3,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)

# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_first, vis_params, 'Albedo')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9efa42238987101318ea68bd3f733deb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9efa42238987101318ea68bd3f733deb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9efa42238987101318ea68bd3f733deb = L.map(
#                 &quot;map_9efa42238987101318ea68bd3f733deb&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdb90ce846a0e767034b31d42479b68c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9efa42238987101318ea68bd3f733deb);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9efa42238987101318ea68bd3f733deb);
#
#
#             var tile_layer_2564429e05f51eeb439406a0bae6ca9b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/6b2030173b7df86f2b958f20fdd6055a-79a5fd90fc09289f38969c9c3b674261/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9efa42238987101318ea68bd3f733deb);
#
#
#             var layer_control_124c1b333f85b436aeca0c0bfe4ee37a = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fdb90ce846a0e767034b31d42479b68c,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Albedo&quot; : tile_layer_2564429e05f51eeb439406a0bae6ca9b,
#                 },
#             };
#             L.control.layers(
#                 layer_control_124c1b333f85b436aeca0c0bfe4ee37a.base_layers,
#                 layer_control_124c1b333f85b436aeca0c0bfe4ee37a.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_9efa42238987101318ea68bd3f733deb);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9efa42238987101318ea68bd3f733deb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Q1. Looking at the image. Answer the following questions?
# a) What does blue signify? What type of landcover is blue?
#
# b) What about the greens ?
#
# c) What are the red color and why?

# %% [markdown]
# ### Your answers here: a) Blue signifies low albedo. Water is typically assigned to blue due to its low albedo. b) Green is associated to vegetation. Green is the albedo level above water, so it might imply that the vegetation is well irrigated. c) Red is accociated with snow. Snow has a really high albedo, high albedo according to the color pallette is returned as red.

# %% [markdown]
# - get ancilliary data

# %%
import sys
sys.path.append('D:\\Backup\\Rouhin_Lenovo\\US_project\\GEE_SEBAL_Project\\geeSEBAL_copy_edits\\etbrasil')
import geesebal
from geesebal import (tools,landsatcollection,masks,meteorology,endmembers, 
evapotranspiration,collection,timeseries,image,ET_Collection_mod)

# %%
### get Bounds of the landsat tile 
geometryReducer=ls_first.geometry().bounds().getInfo()
#  Get weather data from ERA-5
col_meteorology= meteorology.get_meteorology(ls_first,time_start);
print("Data contains: ",col_meteorology.bandNames().getInfo())
# Get Elevation data from SRTM 
SRTM_ELEVATION ='USGS/SRTMGL1_003'
srtm = ee.Image(SRTM_ELEVATION).clip(geometryReducer);
z_alt = srtm.select('elevation')
# Out:
# Data contains:  ['Rn24h_G', 'AirT_G', 'RH_G', 'ux_G', 'SW_Down']

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['AirT_G'],
  'min': 5,
  'max': 35,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)

# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(col_meteorology, vis_params, 'Air Temp (ERA-5)')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1aeb6eca0e0a1eca6382efec0c995fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1aeb6eca0e0a1eca6382efec0c995fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1aeb6eca0e0a1eca6382efec0c995fb = L.map(
#                 &quot;map_e1aeb6eca0e0a1eca6382efec0c995fb&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc7b8b0ecacaa65cbeee357decb7f3cd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1aeb6eca0e0a1eca6382efec0c995fb);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1aeb6eca0e0a1eca6382efec0c995fb);
#
#
#             var tile_layer_f30d736d30c149ea648989a8c235200a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/9532579d0cbec09743ec7ac747600065-767d1c97f58a802f70bdfa0ddcfece00/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1aeb6eca0e0a1eca6382efec0c995fb);
#
#
#             var layer_control_092c75cf0f11f1fb4a88a92a51811d22 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dc7b8b0ecacaa65cbeee357decb7f3cd,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Air Temp (ERA-5)&quot; : tile_layer_f30d736d30c149ea648989a8c235200a,
#                 },
#             };
#             L.control.layers(
#                 layer_control_092c75cf0f11f1fb4a88a92a51811d22.base_layers,
#                 layer_control_092c75cf0f11f1fb4a88a92a51811d22.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_e1aeb6eca0e0a1eca6382efec0c995fb);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e1aeb6eca0e0a1eca6382efec0c995fb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ls_first.bandNames().getInfo()
# Out:
# ['UB', 'B', 'GR', 'R', 'NIR', 'SWIR_1', 'SWIR_2', 'ST_B10', 'pixel_qa', 'ALFA']

# %%
#SPECTRAL INDICES MODULE
def fexp_spec_ind(image):
## Enter code for all the vegetation indices
    #NORMALIZED DIFFERENCE VEGETATION INDEX (NDVI)
    ndvi = image.normalizedDifference(['NIR', 'R']).rename('NDVI');

    #SOIL ADHUSTED VEGETATION INDEX (SAVI)
    savi = image.expression(
      '((1 + 0.5)*(B5 - B4)) / (0.5 + (B5 + B4))', {
        'B4': image.select('R'),
        'B5': image.select('NIR'),
    }).rename('SAVI');

    #NORMALIZED DIFFERENCE WATER INDEX (NDWI)
    ndwi = image.normalizedDifference(['GR', 'NIR']).rename('NDWI');
    
    savi1 = savi.where(savi.gt(0.689), 0.689);

    #LEAF AREA INDEX (LAI)
    lai = image.expression(
      '-(log(( 0.69-SAVI)/0.59 ) / 0.91)', {'SAVI': savi1}).rename('LAI');

    NDVI_adjust=(ndvi.clamp(0.0, 1.00))
    fipar = (NDVI_adjust.multiply(1).subtract(ee.Number(0.05))).rename('fipar')
    fipar = fipar.clamp(0,1)

    #BROAD-BAND SURFACE EMISSIVITY (e_0)
    e_0 = image.expression(
      '0.95 + 0.01 * LAI',{
        'LAI': lai});
    e_0 = e_0.where(lai.gt(3), 0.98).rename('e_0');

    #NARROW BAND TRANSMISSIVITY (e_NB)
    e_NB = image.expression(
      '0.97 + (0.0033 * LAI)',{'LAI': lai});
    e_NB = e_NB.where(lai.gt(3), 0.98).rename('e_NB');
    log_eNB = e_NB.log();

    #LAND SURFACE TEMPERATURE (LST) [K]
    lst=image.select("ST_B10").rename("T_LST")

    #FOR FUTHER USE
    pos_ndvi = ndvi.updateMask(ndvi.gt(0)).rename('pos_NDVI');
    ndvi_neg = pos_ndvi.multiply(-1).rename('NDVI_neg');
    lst_neg = lst.multiply(-1).rename('LST_neg');
    int_ = ee.Image(1).rename('int');
    lst_nw = lst.updateMask(ndwi.lte(0)).rename('LST_NW');
    sd_ndvi = ee.Image(1).rename('sd_ndvi');
    # ls_first=fexp_spec_ind(ls_first);

    #ADD BANDS
    image = image.addBands([ndvi,savi,lst,lai,e_0,e_NB,ndvi_neg,pos_ndvi,int_, sd_ndvi, ndwi,lst_neg,lst_nw]);
    return image
ls_first=fexp_spec_ind(ls_first)

# %%
### Transmissivity
def get_trans(image, z_alt, T_air, UR,SUN_ELEVATION,hour,minuts):
    #ATMOSPHERIC PRESSURE [KPA]
    #SHUTTLEWORTH (2012)
    pres = image.expression(
       '101.3 * ((293 - (0.0065 * Z))/ 293) ** 5.26 ', {
       'Z' : z_alt}).rename('P_ATM')

    #SATURATION VAPOR PRESSURE (es) [KPA]
    es = image.expression(
       ' 0.6108 *(exp( (17.27 * T_air) / (T_air + 237.3)))', {
       'T_air': T_air}).rename('ES')

    #ACTUAL VAPOR PRESSURE (ea) [KPA]
    ea = es.multiply(UR).divide(100).rename('EA')

    #WATER IN THE ATMOSPHERE [mm]
    #Garrison and Adler (1990)
    W = image.expression(
       '(0.14 * EA * PATM) + 2.1', {
       'PATM' : pres,
       'EA' : ea}).rename('W_ATM')

    #SOLAR ZENITH ANGLE OVER A HORZONTAL SURFACE
    solar_zenith = ee.Number(90).subtract(ee.Number(SUN_ELEVATION))
    degree2radian = 0.01745
    solar_zenith_radians = solar_zenith.multiply(ee.Number(degree2radian))
    cos_theta = solar_zenith_radians.cos()

    #BROAD-BAND ATMOSPHERIC TRANSMISSIVITY (tao_sw)
    #ASCE-EWRI (2005)
    ## -------------------------------------Enter code for emmissivity
    tao_sw = image.expression(
       '0.35 + 0.627 * exp(((-0.00146 * P)/(Kt * cos_theta)) - (0.075 * (W / cos_theta)**0.4))', {
       'P' : pres,
       'W': W,
       'Kt' : ee.Number(1),
       'cos_theta' : cos_theta}).rename('Tao_sw')
    
    #MASKS FOR SELECT PRE-CANDIDATES PIXELS
    lst_neg = image.select("ST_B10").multiply(-1).rename('LST_neg');
    ndwi = image.select('NDWI');

    lst_nw = image.select("ST_B10").updateMask(ndwi.lte(0)).rename('LST_NW');

    #ADD BANDS
    image=image.addBands([lst_neg, lst_nw,tao_sw,ea,W])

    return image
ls_trans=get_trans(ls_first,z_alt,col_meteorology.select("AirT_G"),col_meteorology.select("RH_G"),sun_elevation,hour,minuts)

# %%
ls_trans.bandNames().getInfo()
# Out:
# ['UB',
#  'B',
#  'GR',
#  'R',
#  'NIR',
#  'SWIR_1',
#  'SWIR_2',
#  'ST_B10',
#  'pixel_qa',
#  'ALFA',
#  'NDVI',
#  'SAVI',
#  'T_LST',
#  'LAI',
#  'e_0',
#  'e_NB',
#  'NDVI_neg',
#  'pos_NDVI',
#  'int',
#  'sd_ndvi',
#  'NDWI',
#  'LST_neg',
#  'LST_NW',
#  'LST_neg_1',
#  'LST_NW_1',
#  'Tao_sw',
#  'EA',
#  'W_ATM']

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium) (1.24.2)
# Requirement already satisfied: requests in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->folium) (2022.12.7)

# %%
# !pip install geemap
# Out:
# Requirement already satisfied: geemap in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (0.20.6)
# Requirement already satisfied: bqplot in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.12.39)
# Requirement already satisfied: colour in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.1.350)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.14.0)
# Requirement already satisfied: geocoder in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (2.0.1)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.17.2)
# Requirement already satisfied: ipytree in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (3.7.1)
# Requirement already satisfied: numpy in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (1.24.2)
# Requirement already satisfied: pandas in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (2.0.0)
# Requirement already satisfied: plotly in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (5.14.1)
# Requirement already satisfied: pyperclip in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (1.8.2)
# Requirement already satisfied: python-box in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (7.0.1)
# Requirement already satisfied: scooby in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geemap) (0.7.1)
# Requirement already satisfied: google-cloud-storage in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.8.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.86.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.28.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium>=0.13.0->geemap) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from folium>=0.13.0->geemap) (3.1.2)
# Requirement already satisfied: ipywidgets in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.0.6)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (2023.2.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from bqplot->geemap) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geocoder->geemap) (8.1.3)
# Requirement already satisfied: future in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from plotly->geemap) (8.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.22.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.12.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.2)
# Requirement already satisfied: colorama in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2022.12.7)
# Requirement already satisfied: decorator in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.57.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.21.12)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.1.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.6)
# Requirement already satisfied: psutil in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3)
# Requirement already satisfied: backcall in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.4.8)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (304)
# Requirement already satisfied: wcwidth in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\chrir\anaconda3\envs\labndvi\lib\site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.21)

# %%
# Added this myself from website
def add_ee_layer(self, ee_image_object, vis_params, name):
    """Adds a method for displaying Earth Engine image tiles to folium map."""
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
    
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['Tao_sw'],
  'min': 0.75,
  'max': 0.85,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
vis_params_ndvi = {
  'bands': ['NDVI'],
  'min': -0.2,
  'max': 0.8,
   'palette': ['blue','red', 'orange',"yellow",'green']}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)

# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_trans, vis_params, 'Transmissivity')
my_map.add_ee_layer(ls_first, vis_params_ndvi, 'NDVI')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3ed59f3c048b1fc286353dd6f7cb8ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3ed59f3c048b1fc286353dd6f7cb8ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3ed59f3c048b1fc286353dd6f7cb8ce = L.map(
#                 &quot;map_e3ed59f3c048b1fc286353dd6f7cb8ce&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1410bb00638d9e8aaa3b6aed59e3b484 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
#
#             var tile_layer_bd388d62ff6555bab3b5f7d46b6ca1a6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/c63c4f6ff7f70d93649c328833bfc493-d632a523f74451296e57841c43a933a2/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
#
#             var tile_layer_ef6adf59cfc69b6ba5f294f623cf0907 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/8ba6d16ff9f63b78aef838d5b6e1235e-43c20185bf91a98bccdf0cfe4ba79b97/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
#
#             var layer_control_8592e016f8f534d6831dfab5356d83e8 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1410bb00638d9e8aaa3b6aed59e3b484,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Transmissivity&quot; : tile_layer_bd388d62ff6555bab3b5f7d46b6ca1a6,
#                     &quot;NDVI&quot; : tile_layer_ef6adf59cfc69b6ba5f294f623cf0907,
#                 },
#             };
#             L.control.layers(
#                 layer_control_8592e016f8f534d6831dfab5356d83e8.base_layers,
#                 layer_control_8592e016f8f534d6831dfab5356d83e8.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e3ed59f3c048b1fc286353dd6f7cb8ce);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#INSTANTANEOUS INCOMING SHORT-WAVE RADIATION (Rs_down) [W M-2]
def fexp_radshort_down(image, z_alt, T_air, UR,SUN_ELEVATION):
    ## Fill the required gaps (Rename Band to Rs_down) 
    #SOLAR CONSTANT
    gsc = ee.Number(1367) #[W M-2]

    #DAY OF THE YEAR
    dateStr = image.date()
    doy = dateStr.getRelative('day', 'year')
    Pi=ee.Number(3.14)

    #INVERSE RELATIVE  DISTANCE EARTH-SUN
    d1 = ee.Number(2).multiply(Pi).divide(ee.Number(365));
    d2 = d1.multiply(doy);
    d3 = d2.cos();
    dr = ee.Number(1).add(ee.Number(0.033).multiply(d3));

    #ATMOSPHERIC PRESSURE [KPA]
    #SHUTTLEWORTH (2012)
    pres = image.expression(
       '101.3 * ((293 - (0.0065 * Z))/ 293) ** 5.26 ', {
       'Z' : z_alt}).rename('P_ATM')

    #SATURATION VAPOR PRESSURE (es) [KPA]
    es = image.expression(
       ' 0.6108 *(exp( (17.27 * T_air) / (T_air + 237.3)))', {
       'T_air': T_air}).rename('ES')

    #ACTUAL VAPOR PRESSURE (ea) [KPA]
    ea = es.multiply(UR).divide(100).rename('EA')

    #WATER IN THE ATMOSPHERE [mm]
    #GARRISON AND ADLER (1990)
    W = image.expression(
       '(0.14 * EA * PATM) + 2.1', {
       'PATM' : pres,
       'EA' : ea, }).rename('W_ATM')

    #SOLAR ZENITH ANGLE OVER A HORIZONTAL SURFACE
    solar_zenith = ee.Number(90).subtract(ee.Number(SUN_ELEVATION))
    degree2radian = 0.01745
    solar_zenith_radians = solar_zenith.multiply(ee.Number(degree2radian))
    cos_theta = solar_zenith_radians.cos()

    #BROAD-BAND ATMOSPHERIC TRANSMISSIVITY (tao_sw)
    #ASCE-EWRI (2005)
    tao_sw = image.expression(
       '0.35 + 0.627 * exp(((-0.00146 * P)/(Kt * cos_theta)) - (0.075 * (W / cos_theta)**0.4))', {
       'P' : pres,
       'W': W,
       'Kt' : ee.Number(1),
       'cos_theta' : cos_theta}).rename('Tao_sw')

    #INSTANTANEOUS SHORT-WAVE RADIATION (Rs_down) [W M-2]
    Rs_down = image.expression(
       '(gsc * cos_theta * tao_sw * dr)', {
       'gsc' : gsc,
       'tao_sw': tao_sw,
       'dr' : dr,
       'cos_theta' : cos_theta}).rename('Rs_down')

    #ADD BANDS
    image =  image.addBands([Rs_down, tao_sw,es,ea]);
    return image
ls_trans=fexp_radshort_down(ls_trans,z_alt,col_meteorology.select("AirT_G"),col_meteorology.select("RH_G"),sun_elevation)

# %%
#INSTANTANEOUS OUTGOING LONG-WAVE RADIATION (Rl_up) [W M-2]
def fexp_radlong_up(image):
 
    ## Enter code (Rename band "Rl_up")

   emi = image.expression('0.95 + (0.01 * LAI)', {
           'LAI' : image.select('LAI')})
   #LAI
   lai = image.select('LAI');
   emi = emi.where(lai.gt(3), 0.98)
   stefBol = ee.Image(5.67e-8)

   Rl_up = image.expression(
      'emi * stefBol * (LST ** 4)', {
      'emi' : emi,
      'stefBol': stefBol,
      'LST': image.select('T_LST')}).rename('Rl_up')

   #ADD BANDS
   image = image.addBands([Rl_up])
   return image
ls_trans=fexp_radlong_up(ls_trans)

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['Rl_up'],
  'min': 400,
  'max': 700,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}

# vis_params_ndvi = {
#   'bands': ['NDVI'],
#   'min': -0.2,
#   'max': 0.8,
#    'palette': ['blue','red', 'orange',"yellow",'green']}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)

# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_trans, vis_params, 'LW_OUT')
# my_map.add_ee_layer(ls_trans, vis_params_sw, 'SW_IN')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_425bb4b8733e7f816e419558166beb29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_425bb4b8733e7f816e419558166beb29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_425bb4b8733e7f816e419558166beb29 = L.map(
#                 &quot;map_425bb4b8733e7f816e419558166beb29&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a67c6667f023f7685280f77497907d47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_425bb4b8733e7f816e419558166beb29);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_425bb4b8733e7f816e419558166beb29);
#
#
#             var tile_layer_3f8ed3a2933662b3e21c8a9acf4ada18 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/9a99e25c9e584555874dd28145cb4e31-bae4a5af28bd3a6ddcf2eaf8e3e8f8fb/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_425bb4b8733e7f816e419558166beb29);
#
#
#             var layer_control_501e8a59764d940d9e766d53dd6094ee = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a67c6667f023f7685280f77497907d47,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;LW_OUT&quot; : tile_layer_3f8ed3a2933662b3e21c8a9acf4ada18,
#                 },
#             };
#             L.control.layers(
#                 layer_control_501e8a59764d940d9e766d53dd6094ee.base_layers,
#                 layer_control_501e8a59764d940d9e766d53dd6094ee.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_425bb4b8733e7f816e419558166beb29);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_425bb4b8733e7f816e419558166beb29);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Incoming Longwave Radiation

# %%
## We need to select a cold pixel
NDVI_cold=5
Ts_cold=20
NDVI_hot=10
Ts_hot=20
p_top_NDVI=ee.Number(NDVI_cold)
p_coldest_Ts=ee.Number(Ts_cold)
p_lowest_NDVI=ee.Number(NDVI_hot)
p_hottest_Ts=ee.Number(Ts_hot)
d_cold_pixel=endmembers.fexp_cold_pixel(ls_trans, geometryReducer, p_top_NDVI, p_coldest_Ts)
d_cold_pixel.getInfo()
# Out:
# {'ndvi': 0.7832890152931213,
#  'sum': 525382,
#  'temp': 295.06224866,
#  'x': None,
#  'y': None}

# %%
def fexp_radlong_down(image, n_Ts_cold):
    ## Enter code (Rename band "Rl_down")
    log_taosw = image.select('Tao_sw').log()
    Rl_down = image.expression(
       '(0.85 * (- log_taosw) ** 0.09) * stefBol * (n_Ts_cold ** 4)  ',{
       'log_taosw' : log_taosw,
       'stefBol': ee.Number(5.67e-8),
       'n_Ts_cold' : n_Ts_cold}).rename('Rl_down')

    #ADD BANDS
    image = image.addBands([Rl_down])
    return image
ls_trans=fexp_radlong_down(ls_trans,ee.Number(d_cold_pixel.get("temp").getInfo()))

# %%
ls_trans.bandNames().getInfo()
# Out:
# ['UB',
#  'B',
#  'GR',
#  'R',
#  'NIR',
#  'SWIR_1',
#  'SWIR_2',
#  'ST_B10',
#  'pixel_qa',
#  'ALFA',
#  'NDVI',
#  'SAVI',
#  'T_LST',
#  'LAI',
#  'e_0',
#  'e_NB',
#  'NDVI_neg',
#  'pos_NDVI',
#  'int',
#  'sd_ndvi',
#  'NDWI',
#  'LST_neg',
#  'LST_NW',
#  'LST_neg_1',
#  'LST_NW_1',
#  'Tao_sw',
#  'EA',
#  'W_ATM',
#  'Rs_down',
#  'Tao_sw_1',
#  'ES',
#  'EA_1',
#  'Rl_up',
#  'Rl_down']

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['Rl_down'],
  'min': 310,
  'max': 325,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
# vis_params_ndvi = {
#   'bands': ['NDVI'],
#   'min': -0.2,
#   'max': 0.8,
#    'palette': ['blue','red', 'orange',"yellow",'green']}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_trans, vis_params, 'LW_IN')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38ec508ec0040d79c6858de62313548b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38ec508ec0040d79c6858de62313548b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38ec508ec0040d79c6858de62313548b = L.map(
#                 &quot;map_38ec508ec0040d79c6858de62313548b&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3f3149ffd4d54aa3158a3a99ef81495 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38ec508ec0040d79c6858de62313548b);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38ec508ec0040d79c6858de62313548b);
#
#
#             var tile_layer_6c020edeebaa41c2a66542384a7dd4d3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/0590bb6b950aeb8fe5ff7c06903ab305-705c324a94d4807cd7b852015bea868b/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38ec508ec0040d79c6858de62313548b);
#
#
#             var layer_control_79e9760f22e746aea5453761869c552c = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b3f3149ffd4d54aa3158a3a99ef81495,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;LW_IN&quot; : tile_layer_6c020edeebaa41c2a66542384a7dd4d3,
#                 },
#             };
#             L.control.layers(
#                 layer_control_79e9760f22e746aea5453761869c552c.base_layers,
#                 layer_control_79e9760f22e746aea5453761869c552c.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_38ec508ec0040d79c6858de62313548b);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_38ec508ec0040d79c6858de62313548b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Net radiation

# %%
def fexp_radbalance(image):
    ## --- Enter code (Rename Band Rn)
    Rn = image.expression(
       '((1-alfa) * Rs_down) + Rl_down - Rl_up - ((1 - e_0) * Rl_down) ', {
       'alfa' : image.select('ALFA'),
       'Rs_down': image.select('Rs_down'),
       'Rl_down' : image.select('Rl_down'),
       'Rl_up' : image.select('Rl_up'),
       'e_0' : image.select('e_0')}).rename('Rn')
    #ADD BANDS
    image = image.addBands(Rn)
    return image
ls_trans=fexp_radbalance(ls_trans)

# %%
ls_trans.bandNames().getInfo()
# Out:
# ['UB',
#  'B',
#  'GR',
#  'R',
#  'NIR',
#  'SWIR_1',
#  'SWIR_2',
#  'ST_B10',
#  'pixel_qa',
#  'ALFA',
#  'NDVI',
#  'SAVI',
#  'T_LST',
#  'LAI',
#  'e_0',
#  'e_NB',
#  'NDVI_neg',
#  'pos_NDVI',
#  'int',
#  'sd_ndvi',
#  'NDWI',
#  'LST_neg',
#  'LST_NW',
#  'LST_neg_1',
#  'LST_NW_1',
#  'Tao_sw',
#  'EA',
#  'W_ATM',
#  'Rs_down',
#  'Tao_sw_1',
#  'ES',
#  'EA_1',
#  'Rl_up',
#  'Rl_down',
#  'Rn']

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['Rn'],
  'min': 350,
  'max': 900,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
# vis_params_ndvi = {
#   'bands': ['NDVI'],
#   'min': -0.2,
#   'max': 0.8,
#    'palette': ['blue','red', 'orange',"yellow",'green']}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_trans, vis_params, 'Net Radiation')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c50296f7f8bc1f86f0f2d11bf12a32eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c50296f7f8bc1f86f0f2d11bf12a32eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c50296f7f8bc1f86f0f2d11bf12a32eb = L.map(
#                 &quot;map_c50296f7f8bc1f86f0f2d11bf12a32eb&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc80d08f5a268052266baca8e43a36f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c50296f7f8bc1f86f0f2d11bf12a32eb);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c50296f7f8bc1f86f0f2d11bf12a32eb);
#
#
#             var tile_layer_37fe3a879312f70281cb8b4111b9dd3e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/f847ab6decfb5e450c2fd9e985f8d9de-e1021c523bcc0599b635ce35c37e2680/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c50296f7f8bc1f86f0f2d11bf12a32eb);
#
#
#             var layer_control_c2b75cccb9a41e12464d72ed8e32d98c = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_bc80d08f5a268052266baca8e43a36f8,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Net Radiation&quot; : tile_layer_37fe3a879312f70281cb8b4111b9dd3e,
#                 },
#             };
#             L.control.layers(
#                 layer_control_c2b75cccb9a41e12464d72ed8e32d98c.base_layers,
#                 layer_control_c2b75cccb9a41e12464d72ed8e32d98c.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c50296f7f8bc1f86f0f2d11bf12a32eb);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c50296f7f8bc1f86f0f2d11bf12a32eb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Q1. Which land cover shows highest net radiation and which shows the lowest?

# %% [markdown]
# Answer Here

# %% [markdown]
# Q2. Why is it high and low in those landcover? (Think which component contributes most to net radiation)

# %% [markdown]
# Answer here

# %% [markdown]
# ### Soil Heat Flux

# %%
#SOIL HEAT FLUX (G) [W M-2]
#BASTIAANSSEN (2000)
def fexp_soil_heat(image):
    ## Enter Code (reName band "G")
    G = image.expression(
        'Rn * (T - 273.15) * ( 0.0038 + (0.0074 * ALFA)) *  (1 - 0.98 * (NDVI ** 4)) ', {
         'Rn' : image.select('Rn'),
         'NDVI': image.select('NDVI'),
         'ALFA': image.select('ALFA'),
         'T': image.select('ST_B10')}).rename('G');
    #ADD BANDS
    image = image.addBands(G);
    return image
ls_trans=fexp_soil_heat(ls_trans)

# %%
ls_trans.bandNames().getInfo()
# Out:
# ['UB',
#  'B',
#  'GR',
#  'R',
#  'NIR',
#  'SWIR_1',
#  'SWIR_2',
#  'ST_B10',
#  'pixel_qa',
#  'ALFA',
#  'NDVI',
#  'SAVI',
#  'T_LST',
#  'LAI',
#  'e_0',
#  'e_NB',
#  'NDVI_neg',
#  'pos_NDVI',
#  'int',
#  'sd_ndvi',
#  'NDWI',
#  'LST_neg',
#  'LST_NW',
#  'LST_neg_1',
#  'LST_NW_1',
#  'Tao_sw',
#  'EA',
#  'W_ATM',
#  'Rs_down',
#  'Tao_sw_1',
#  'ES',
#  'EA_1',
#  'Rl_up',
#  'Rl_down',
#  'Rn',
#  'G']

# %%
# Set visualization parameters.
folium.Map.add_ee_layer = add_ee_layer
vis_params = {
  'bands': ['G'],
  'min': 40,
  'max': 140,
   'palette': ['blue', 'green', 'yellow', 'orange',"red"]}
# vis_params_ndvi = {
#   'bands': ['NDVI'],
#   'min': -0.2,
#   'max': 0.8,
#    'palette': ['blue','red', 'orange',"yellow",'green']}
# Create a folium map object.
my_map = folium.Map(location=[35, -120], zoom_start=4, height=500)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
# basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
my_map.add_ee_layer(ls_trans, vis_params, 'Soil Heat')

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea691fc5f380d90b5318229f67b53dcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea691fc5f380d90b5318229f67b53dcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea691fc5f380d90b5318229f67b53dcb = L.map(
#                 &quot;map_ea691fc5f380d90b5318229f67b53dcb&quot;,
#                 {
#                     center: [35.0, -120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b6d22c878461c39446ee26e56ba5479 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea691fc5f380d90b5318229f67b53dcb);
#
#
#             var tile_layer_a3b6198644f431a3e390ce388ff0f20e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea691fc5f380d90b5318229f67b53dcb);
#
#
#             var tile_layer_b384fb9daee7dbdecb73dcce5a1df279 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/9ce3702c73480694e7dc9dd5618ec911-a0af05d74853daeb0227e54ab5bcec67/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea691fc5f380d90b5318229f67b53dcb);
#
#
#             var layer_control_f023f0282fec4572482a92ae5cf36ddd = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_4b6d22c878461c39446ee26e56ba5479,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_a3b6198644f431a3e390ce388ff0f20e,
#                     &quot;Soil Heat&quot; : tile_layer_b384fb9daee7dbdecb73dcce5a1df279,
#                 },
#             };
#             L.control.layers(
#                 layer_control_f023f0282fec4572482a92ae5cf36ddd.base_layers,
#                 layer_control_f023f0282fec4572482a92ae5cf36ddd.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_ea691fc5f380d90b5318229f67b53dcb);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ea691fc5f380d90b5318229f67b53dcb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Q4. What influences soil heat flux? Can you find a logical explanation of what you see?

# %% [markdown]
# Answer here

# %% [markdown]
# ### Sensible Heat Flux

# %%
##HOT PIXEL
d_hot_pixel=endmembers.fexp_hot_pixel(ls_trans, geometryReducer,p_lowest_NDVI, p_hottest_Ts)
# ##SENSIBLE HEAT FLUX (H) [W M-2]
ls_trans=tools.fexp_sensible_heat_flux(ls_trans, col_meteorology.select("ux_G"), col_meteorology.select("RH_G"),col_meteorology.select("Rn24h_G"),ee.Number(d_cold_pixel.get("temp").getInfo()) \
                                       ,d_hot_pixel,date_string,geometryReducer)
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[34], line 4
#       2 d_hot_pixel=endmembers.fexp_hot_pixel(ls_trans, geometryReducer,p_lowest_NDVI, p_hottest_Ts)
#       3 # ##SENSIBLE HEAT FLUX (H) [W M-2]
# ----> 4 ls_trans=tools.fexp_sensible_heat_flux(ls_trans, col_meteorology.select("ux_G"), col_meteorology.select("RH_G"),col_meteorology.select("Rn24h_G"),ee.Number(d_cold_pixel.get("temp").getInfo()) \
#       5                                        ,d_hot_pixel,date_string,geometryReducer)
#
# File D:\Backup\Rouhin_Lenovo\US_project\GEE_SEBAL_Project\geeSEBAL_copy_edits\etbrasil\geesebal\tools.py:487, in fexp_sensible_heat_flux(image, ux, UR, Rn24hobs, n_Ts_cold, d_hot_pixel, date_string, refpoly)
#     485 n_Rn_hot = ee.Number(d_hot_pixel.get('Rn').getInfo())
#     486 #LAT AND LON HOT PIXEL
# --> 487 n_long_hot = ee.Number(d_hot_pixel.get('x').getInfo())
#     488 n_lat_hot = ee.Number(d_hot_pixel.get('y').getInfo())
#     489 #POINT GEOMETRY
#
# File c:\Users\rouhi\anaconda3\envs\rs\Lib\site-packages\ee\computedobject.py:28, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      26   return args[0]
#      27 else:
# ---> 28   return type.__call__(cls, *args, **kwargs)
#
# File c:\Users\rouhi\anaconda3\envs\rs\Lib\site-packages\ee\ee_number.py:43, in Number.__init__(self, number)
#      41   self._number = None
#      42 else:
# ---> 43   raise ee_exception.EEException(
#      44       'Invalid argument specified for ee.Number(): %s' % number)
#
# EEException: Invalid argument specified for ee.Number(): None

# %% [markdown]
# ### Final Task
# Calculate Latent Heat Flux (LE) as residual energy Balance and plot it

# %% [markdown]
# ### Deliverables
#
# - Plots
#     - All components of Radiation
#     - H, LE and G fluxes
# - This Jupyter Notebook(.ipnyb)
